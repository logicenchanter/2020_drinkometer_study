# %%
import pandas as pd
import numpy as np
from datetime import date
from os import listdir
from os.path import isfile, join

# %%
df_main = pd.read_excel("drinkometer_df_w_1001_1_consumption.xlsx")

# %%
df_main = pd.read_excel("drinkometer_df_w_1001_1_consumption.xlsx")
file_skipped = pd.read_excel("01/1 25.03 from 2000.Jan.03  00-52-32 to 2000.Feb.14  18-42-32 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("01/1 from 2020.Mrz.25  13-21-39 to 2020.Mai.17  05-46-39 -- 1.xlsx", skiprows=18)  
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("01/1 from 2020.Mai.19  14-19-16 to 2020.Jul.20  01-54-16 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

file_skipped = pd.read_excel("01/1 from 2020.Jul.22  13-10-11 to 2020.Sep.25  17-55-11 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

file_skipped = pd.read_excel("01/1 from 2020.Sep.30  14-52-56 to 2020.Nov.13  05-17-56 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1001_1_consumption_wloco.xlsx', index=False, header=True)



df_h = pd.read_excel("drinkometer_df_w_1001_1_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1001_1_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1001_1_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1001_1_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1001_1_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1001_1_daily_dark_wloco.xlsx', index=False, header=True)

# %%
df_main = pd.read_excel("drinkometer_df_w_1002_2_consumption.xlsx")

# %%
df_main.head()
# Out:
#          date      time  day_index  hour_index  animal  box  strain state  \
# 0  2020-02-12  00:00:00          1           1    1002    2  Wistar  dark
# 1  2020-02-12  00:01:00          1           1    1002    2  Wistar  dark
# 2  2020-02-12  00:02:00          1           1    1002    2  Wistar  dark
# 3  2020-02-12  00:03:00          1           1    1002    2  Wistar  dark
# 4  2020-02-12  00:04:00          1           1    1002    2  Wistar  dark
#
#   oxytocin quinine  water  alcohol-5%  alcohol-10%  alcohol-20%  locomotive
# 0      NaN     NaN    NaN         NaN          NaN          NaN         NaN
# 1      NaN     NaN    NaN         NaN          NaN          NaN         NaN
# 2      NaN     NaN    NaN         NaN          NaN          NaN         NaN
# 3      NaN     NaN    NaN         NaN          NaN          NaN         NaN
# 4      NaN     NaN    NaN         NaN          NaN          NaN         NaN

# %%
df_main = pd.read_excel("drinkometer_df_w_1002_2_consumption.xlsx")

file_skipped = pd.read_excel("02/2 from 2020.Feb.17  13-24-00 to 2020.Mrz.03  01-54-00 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("02/2 from 2020.Aug.17  09-59-23 to 2020.Sep.24  07-54-23 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

file_skipped = pd.read_excel("02/2 from 2020.Sep.30  14-53-19 to 2020.Okt.02  11-13-19 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1002_2_consumption_wloco.xlsx', index=False, header=True)

# %%
df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1002_2_consumption_wloco.xlsx', index=False, header=True)

# %%
df_h = pd.read_excel("drinkometer_df_w_1002_2_hourly.xlsx")

# %%
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1002_2_hourly_wloco.xlsx', index=False, header=True)

# %%
df_d_light = pd.read_excel("drinkometer_df_w_1002_2_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1002_2_daily_dark.xlsx")

# %%
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1002_2_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1002_2_daily_dark_wloco.xlsx', index=False, header=True)

# %%
#df_main = pd.read_excel("drinkometer_df_w_1003_3_consumption.xlsx")
file_skipped = pd.read_excel("03/3 from 2020.Feb.05  14-42-39 to 2020.Mai.27  11-32-39 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("03/3 from 2020.Jun.04  14-22-29 to 2020.Sep.26  08-17-29 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("03/3 from 2020.Sep.30  14-53-47 to 2020.Nov.18  19-03-47 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity


df_h = pd.read_excel("drinkometer_df_w_1003_3_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1003_3_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1003_3_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1003_3_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1003_3_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1003_3_daily_dark_wloco.xlsx', index=False, header=True)

# %%
#df_main = pd.read_excel("drinkometer_df_w_1004_4_consumption.xlsx")
file_skipped = pd.read_excel("04/4 04.06 from 2000.Jan.03  00-50-54 to 2000.Apr.12  20-40-54 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel
daily_dark_wloco.xlsx', index=False, header=True)

# %%
df_main = pd.read_excel("drinkometer_df_w_1029_29_consumption.xlsx")
file_skipped = pd.read_excel("29/29 from 2020.Feb.10  12-06-08 to 2020.Mai.31  09-26-08 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("29/29 from 2020.Jun.04  14-24-31 to 2020.Sep.25  20-19-31 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("29/29 from 2020.Sep.30  14-55-58 to 2020.Nov.18  19-00-58 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity




df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1029_29_consumption_wloco.xlsx', index=False, header=True)

df_h = pd.read_excel("drinkometer_df_w_1029_29_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1029_29_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1029_29_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1029_29_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1029_29_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1029_29_daily_dark_wloco.xlsx', index=False, header=True)

# %%
df_main = pd.read_excel("drinkometer_df_w_1030_30_consumption.xlsx")
file_skipped = pd.read_excel("30/30 from 2020.Feb.10  12-06-17 to 2020.Mai.29  22-56-17 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("30/30 from 2020.Jun.04  14-24-45 to 2020.Aug.11  16-54-45 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity



df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_30_consumption_wloco.xlsx', index=False, header=True)

df_h = pd.read_excel("drinkometer_df_w_1030_30_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_30_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1030_30_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1030_30_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_30_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_30_daily_dark_wloco.xlsx', index=False, header=True)

# %%
df_main = pd.read_excel("drinkometer_df_w_1031_31_consumption.xlsx")
file_skipped = pd.read_excel("31/31 from 2020.Feb.10  12-06-41 to 2020.Mai.26  00-31-41 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("31/31 from 2020.Jun.04  14-25-02 to 2020.Sep.26  08-20-02 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("31/31 from 2020.Sep.30  14-56-09 to 2020.Nov.18  19-01-09 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity




df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_31_consumption_wloco.xlsx', index=False, header=True)

df_h = pd.read_excel("drinkometer_df_w_1031_31_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1030_31_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1031_31_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1031_31_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1031_31_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1031_31_daily_dark_wloco.xlsx', index=False, header=True)

# %%
df_main = pd.read_excel("drinkometer_df_w_1032_32_consumption.xlsx")
file_skipped = pd.read_excel("32/32 from 2020.Feb.17  13-24-14 to 2020.Mai.22  02-44-14 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('{}-%m-%d'.format(str(2020)))
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity

    
file_skipped = pd.read_excel("32/32 from 2020.Jun.04  14-25-16 to 2020.Sep.15  21-00-16 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity
    
file_skipped = pd.read_excel("32/32 from 2020.Sep.22  10-16-38 to 2020.Nov.18  19-01-38 -- 1.xlsx", skiprows=18)
reform_length = len(file_skipped)
for index_ref in range(reform_length):
    lf_date = file_skipped['Date, Time'][index_ref].strftime('%Y-%m-%d')
    lf_time = file_skipped['Date, Time'][index_ref].strftime('%H:%M:{}'.format(str('00')))
    lf_activity = file_skipped['Activity (detection(s))'][index_ref]
    index_value = df_main[(df_main['date'] == lf_date ) & (df_main['time'] == lf_time)].index
    df_main.loc[index_value, 'locomotive'] = lf_activity




df_main.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1032_32_consumption_wloco.xlsx', index=False, header=True)

df_h = pd.read_excel("drinkometer_df_w_1032_32_hourly.xlsx")
number_of_days = 280
for hour in range(1, number_of_days*24+1):
    list_ = []
    ind = np.array(df_h.loc[(df_h['hour_index'] == hour)].index)
    df_extracted = df_main.loc[(df_main['hour_index'] == hour) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_h.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_h.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1032_32_hourly_wloco.xlsx', index=False, header=True)

df_d_light = pd.read_excel("drinkometer_df_w_1032_32_daily_light.xlsx")
df_d_dark = pd.read_excel("drinkometer_df_w_1032_32_daily_dark.xlsx")
for day in range(1, number_of_days+1):
    list_ = []
    ind = np.array(df_d_light.loc[(df_d_light['day_index'] == day)].index)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('light')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_light.loc[ind, 'locomotive'] = np.nansum(temp_arr)
    df_extracted = df_main.loc[(df_main['day_index'] == day) & (df_main['state'] == str('dark')) & (df_main['locomotive'].notnull())]
    temp_arr = np.array(df_extracted['locomotive'])
    if len(temp_arr) > 1:
        df_d_dark.loc[ind, 'locomotive'] = np.nansum(temp_arr)
df_d_light.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1032_32_daily_light_wloco.xlsx', index=False, header=True)
df_d_dark.to_excel(r'C:/Users/mehrd/Desktop/work/results/drinkometer_df_w_1032_32_daily_dark_wloco.xlsx', index=False, header=True)
