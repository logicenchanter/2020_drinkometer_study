# %%
import scipy
import joblib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sys
sys.modules['sklearn.externals.joblib'] = joblib
from jive.AJIVE import AJIVE
from jive.PCA import PCA
from jive.ajive_fig2 import generate_data_ajive_fig2
from jive.viz.block_visualization import data_block_heatmaps, jive_full_estimate_heatmaps

# %%
import pickle
with open('ADE7_q_dark_loco.pkl','wb') as f:
    pickle.dump(X, f)
f.close()

with open('ADE7_q_light_loco.pkl','wb') as f:
    pickle.dump(Y, f)
f.close()

# %%
path_ = os.getcwd()
#print(path_)
path_ = os.chdir('C:\\Users\\mehrd\\Documents\\datasets')

df = pd.read_excel('drinkometer_df_wistar_male_1001_1_consumption.xlsx')
df_temp = df.loc[332641:342720]
x1 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x1 = x1[~np.isnan(x1)]

y1 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y1 = y1[~np.isnan(y1)]

df = pd.read_excel('drinkometer_df_wistar_male_1003_3_consumption.xlsx')
df_temp = df.loc[332641:342720]
x3 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x3 = x3[~np.isnan(x3)]
y3 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y3 = y3[~np.isnan(y3)]

df = pd.read_excel('drinkometer_df_wistar_male_1004_4_consumption.xlsx')
df_temp = df.loc[332641:342720]
x4 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x4 = x4[~np.isnan(x4)]
y4 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y4 = y4[~np.isnan(y4)]


df = pd.read_excel('drinkometer_df_wistar_male_1005_5_consumption.xlsx')
df_temp = df.loc[332641:342720]
x5 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x5 = x5[~np.isnan(x5)]
y5 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y5 = y5[~np.isnan(y5)]

df = pd.read_excel('drinkometer_df_wistar_male_1006_6_consumption.xlsx')
df_temp = df.loc[332641:342720]
x6 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x6 = x6[~np.isnan(x6)]
y6 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y6 = y6[~np.isnan(y6)]


df = pd.read_excel('drinkometer_df_wistar_male_1008_8_consumption.xlsx')
df_temp = df.loc[332641:342720]
x8 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x8 = x8[~np.isnan(x8)]
y8 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y8 = y8[~np.isnan(y8)]

df = pd.read_excel('drinkometer_df_wistar_male_1010_10_consumption.xlsx')
df_temp = df.loc[332641:342720]
x10 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x10 = x10[~np.isnan(x10)]
y10 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y10 = y10[~np.isnan(y10)]


df = pd.read_excel('drinkometer_df_wistar_male_1011_11_consumption.xlsx')
df_temp = df.loc[332641:342720]
x11 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x11 = x11[~np.isnan(x11)]
y11 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y11 = y11[~np.isnan(y11)]

df = pd.read_excel('drinkometer_df_wistar_male_1013_13_consumption.xlsx')
df_temp = df.loc[332641:342720]
x13 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x13 = x13[~np.isnan(x13)]
y13 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y13 = y13[~np.isnan(y13)]


df = pd.read_excel('drinkometer_df_wistar_male_1014_14_consumption.xlsx')
df_temp = df.loc[332641:342720]
x14 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x14 = x14[~np.isnan(x14)]
y14 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y14 = y14[~np.isnan(y14)]


df = pd.read_excel('drinkometer_df_wistar_male_1015_15_consumption.xlsx')
df_temp = df.loc[332641:342720]
x15 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x15 = x15[~np.isnan(x15)]
y15 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y15 = y15[~np.isnan(y15)]

df = pd.read_excel('drinkometer_df_wistar_male_1017_17_consumption.xlsx')
df_temp = df.loc[332641:342720]
x17 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x17 = x17[~np.isnan(x17)]
y17 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y17 = y17[~np.isnan(y17)]

df = pd.read_excel('drinkometer_df_wistar_male_1018_18_consumption.xlsx')
df_temp = df.loc[332641:342720]
x18 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x18 = x18[~np.isnan(x18)]
y18 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y18 = y18[~np.isnan(y18)]

df = pd.read_excel('drinkometer_df_wistar_male_1019_19_consumption.xlsx')
df_temp = df.loc[332641:342720]
x19 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x19 = x19[~np.isnan(x19)]
y19 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y19 = y19[~np.isnan(y19)]


df = pd.read_excel('drinkometer_df_wistar_male_1020_20_consumption.xlsx')
df_temp = df.loc[332641:342720]
x20 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x20 = x20[~np.isnan(x20)]
y20 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y20 = y20[~np.isnan(y20)]

df = pd.read_excel('drinkometer_df_wistar_male_1021_21_consumption.xlsx')
df_temp = df.loc[332641:342720]
x21 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x21 = x21[~np.isnan(x21)]
y21 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y21 = y21[~np.isnan(y21)]

df = pd.read_excel('drinkometer_df_wistar_male_1022_22_consumption.xlsx')
df_temp = df.loc[332641:342720]
x22 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x22 = x22[~np.isnan(x22)]
y22 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y22 = y22[~np.isnan(y22)]

df = pd.read_excel('drinkometer_df_wistar_male_1023_23_consumption.xlsx')
df_temp = df.loc[332641:342720]
x23 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x23 = x23[~np.isnan(x23)]
y23 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y23 = y23[~np.isnan(y23)]

df = pd.read_excel('drinkometer_df_wistar_male_1024_24_consumption.xlsx')
df_temp = df.loc[332641:342720]
x24 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x24 = x24[~np.isnan(x24)]
y24 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y24 = y24[~np.isnan(y24)]

df = pd.read_excel('drinkometer_df_wistar_male_1025_25_consumption.xlsx')
df_temp = df.loc[332641:342720]
x25 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x25 = x25[~np.isnan(x25)]
y25 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y25 = y25[~np.isnan(y25)]

df = pd.read_excel('drinkometer_df_wistar_male_1026_26_consumption.xlsx')
df_temp = df.loc[332641:342720]
x26 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x26 = x26[~np.isnan(x26)]
y26 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y26 = y26[~np.isnan(y26)]


df = pd.read_excel('drinkometer_df_wistar_male_1027_27_consumption.xlsx')
df_temp = df.loc[332641:342720]
x27 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x27 = x27[~np.isnan(x27)]
y27 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y27 = y27[~np.isnan(y27)]

df = pd.read_excel('drinkometer_df_wistar_male_1029_29_consumption.xlsx')
df_temp = df.loc[332641:342720]
x29 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x29 = x29[~np.isnan(x29)]
y29 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y29 = y29[~np.isnan(y29)]

df = pd.read_excel('drinkometer_df_wistar_male_1031_31_consumption.xlsx')
df_temp = df.loc[332641:342720]
x31 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x31 = x31[~np.isnan(x31)]
y31 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y31 = y31[~np.isnan(y31)]

df = pd.read_excel('drinkometer_df_wistar_male_1032_32_consumption.xlsx')
df_temp = df.loc[332641:342720]
x32 = df_temp.loc[df_temp['state'] == str("dark")]['locomotive'].values
x32 = x32[~np.isnan(x32)]
y32 = df_temp.loc[df_temp['state'] == str("light")]['locomotive'].values
y32 = y32[~np.isnan(y32)]

# %%
print(len(x1))
print(len(x3))
print(len(y1))
print(len(y3))
# Out:
# 864
# 864
# 864
# 864

# %%
X = np.empty((26, len(x1)), dtype=float)
X[0][:] = np.arange(1, len(x1)+1)
X[1][:] = x1
X[2][:] = x3
X[3][:] = x4
X[4][:] = x5
X[5][:] = x6
X[6][:] = x8
X[7][:] = x10
X[8][:] = x11
X[9][:] = x13
X[10][:] = x14
X[11][:] = x15
X[12][:] = x17
X[13][:] = x18
X[14][:] = x19
X[15][:] = x20
X[16][:] = x21
X[17][:] = x22
X[18][:] = x23
X[19][:] = x24
X[20][:] = x25
X[21][:] = x26
X[22][:] = x27
X[23][:] = x29
X[24][:] = x31
X[25][:] = x32

Y = np.empty((26, len(y1)), dtype=float)
Y[0][:] = np.arange(1, len(y1)+1)
Y[1][:] = y1
Y[2][:] = y3
Y[3][:] = y4
Y[4][:] = y5
Y[5][:] = y6
Y[6][:] = y8
Y[7][:] = y10
Y[8][:] = y11
Y[9][:] = y13
Y[10][:] = y14
Y[11][:] = y15
Y[12][:] = y17
Y[13][:] = y18
Y[14][:] = y19
Y[15][:] = y20
Y[16][:] = y21
Y[17][:] = y22
Y[18][:] = y23
Y[19][:] = y24
Y[20][:] = y25
Y[21][:] = y26
Y[22][:] = y27
Y[23][:] = y29
Y[24][:] = y31
Y[25][:] = y32

# %%
data_block_heatmaps([X, Y])
plt.savefig("block_heatmaps.png", dpi=150)
plt.show()

# %%
# determine initial signal ranks by inspecting scree plots
plt.figure(figsize=[10, 5])
plt.subplot(1, 2, 1)
PCA().fit(X).plot_scree()
plt.savefig("signal value_dph.png", dpi=150)
plt.show()
plt.subplot(1, 2, 2)
PCA().fit(Y).plot_scree()
plt.savefig("signal value_lph.png", dpi=150)
plt.show()

# %%
ajive = AJIVE(init_signal_ranks={'x': 1})
ajive.fit(blocks={'x': X})

plt.figure(figsize=[10, 20])
jive_full_estimate_heatmaps(ajive.get_full_block_estimates(),
                            blocks={'x': X})
plt.savefig("full_block_estimates_dph.png", dpi=150)
plt.show()

# %%
ajive.plot_joint_diagnostic()
plt.savefig("joint_diagnostic_dph.png", dpi=150)
plt.show()

# %%
ajive = AJIVE(init_signal_ranks={'y': 1})
ajive.fit(blocks={'y': Y})

plt.figure(figsize=[10, 20])
jive_full_estimate_heatmaps(ajive.get_full_block_estimates(),
                            blocks={'y': Y})
plt.savefig("full_block_estimates_lph.png", dpi=150)
plt.show()

# %%
ajive.plot_joint_diagnostic()
plt.savefig("joint_diagnostic_lph.png", dpi=150)
plt.show()
